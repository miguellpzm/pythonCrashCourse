# %% [markdown]
# # Creating and using a class

# %%
class Dog():

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def sit(self):
        print(self.name.title() + " is now sitting")

    def roll_over(self):
        print(self.name.title() + " rolled over!")

# %%
# making an instance from a class

my_dog = Dog("dory", 7)

print("My dog´s name is " + my_dog.name.title())
print("My dog is " + str(my_dog.age) + " years old")
# Out:
# My dog´s name is Dory
# My dog is 7 years old

# %%
# calling methods

my_dog.sit()
my_dog.roll_over()
# Out:
# Dory is now sitting
# Dory rolled over!

# %%
# creating multiple instances

yourDog = Dog("lucy", 2)

print("Your name's dog is " + yourDog.name.title())
print("Your dog is " + str(yourDog.age) + " years old" )
yourDog.sit()
# Out:
# Your name's dog is Lucy
# Your dog is 2 years old
# Lucy is now sitting

# %%
# try it yourself

class Restaurant():

    def __init__(self, restaurantName, cuisineType):
        self.restaurantName = restaurantName
        self.cuisineType = cuisineType

    def describeRestaurant(self):
        print("The name´s restaurant is" + self.restaurantName)
        print("Our cuisine is " + self.cuisineType)

    def openRestaurant():
        print("The restaurant is open!")

restaurant = Restaurant("La cañadita", "mexicana")
print(restaurant.restaurantName)
print(restaurant.cuisineType)

print("\n" + restaurant.restaurantName + " is a restaurant that cook " +
      restaurant.cuisineType + " food")
# Out:
# La cañadita
# mexicana
#
# La cañadita is a restaurant that cook mexicana food

# %%
restaurant1 = Restaurant("vicenci", "pizza")
restaurant2 = Restaurant("panda express", "chinese")

print("\n" + restaurant1.restaurantName + " is a restaurant that cook " +
      restaurant1.cuisineType + " food")

print("\n" + restaurant2.restaurantName + " is a restaurant that cook " +
      restaurant2.cuisineType + " food")
# Out:
# vicenci is a restaurant that cook pizza food
#
# panda express is a restaurant that cook chinese food

# %%
class User():
    def __init__(self, first, last, age, nat):
        self.first = first
        self.last = last
        self.age = age
        self.nat = nat

    def describeUser(self):
        print("\nFirst name: " + self.first.title())
        print("Last name: " + self.last.title())
        print("Age: " + str(self.age))
        print("Nationality: " + self.nat)

    def greetUser(self):
        print("\nHi, " + self.first.title() + " welcome to my hotel")

# %%
user1 = User("Miguel", "Marquez", 21, "mexicana")
user1.describeUser()
user1.greetUser()

user2 = User("Dory", "Marquez", 7, "mexico-alemana")
user2.describeUser()
user2.greetUser()

user3 = User("Carlos", "Uranga", 21, "mexicana")
user3.describeUser()
user3.greetUser()
# Out:
# First name: Miguel
# Last name: Marquez
# Age: 21
# Nationality: mexicana
#
# Hi, Miguel welcome to my hotel
#
# First name: Dory
# Last name: Marquez
# Age: 7
# Nationality: mexico-alemana
#
# Hi, Dory welcome to my hotel
#
# First name: Carlos
# Last name: Uranga
# Age: 21
# Nationality: mexicana
#
# Hi, Carlos welcome to my hotel

# %% [markdown]
# # working with classes and instances

# %%
class Car():
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer = 10

    def getDescriptive(self):
        long_name = str(self.year) + " " + self.make + " " + self.model
        return long_name.title()

    def readOdometer(self):
        print("This car has " + str(self.odometer) + " miles on it")

    def updateOdometer(self, mileage):
        if mileage >= self.odometer:
            self.odometer = mileage
        else:
            print("You can´t roll back an odometer!")

    def incrementOdometer(self, miles):
        self.odometer += miles

myNewCar = Car("audi", "a4", 2016)
myUsedCar = Car("subaru", "outback", 2013)

print(myNewCar.getDescriptive())

myNewCar.odometer = 23
myNewCar.readOdometer()

myNewCar.updateOdometer(9)
myNewCar.readOdometer()

myUsedCar.updateOdometer(23500)
myUsedCar.readOdometer()

myUsedCar.incrementOdometer(100)
myUsedCar.readOdometer()
# Out:
# 2016 Audi A4
# This car has 23 miles on it
# You can´t roll back an odometer!
# This car has 23 miles on it
# This car has 23500 miles on it
# This car has 23600 miles on it

# %%
# try it yourself

class Restaurant():

    def __init__(self, restaurantName, cuisineType, numberServed):
        self.restaurantName = restaurantName
        self.cuisineType = cuisineType
        self.numberServed = 2

    def describeRestaurant(self):
        print("The name´s restaurant is" + self.restaurantName)
        print("Our cuisine is " + self.cuisineType)

    def openRestaurant():
        print("The restaurant is open!")

    def restaurantCustomers(self):
        print(self.numberServed)

    def updateCostumers(self, updateCostum):
        self.numberServed = updateCostum

    def incrementNumberServed(self, served):
        self.numberServed += served

# %%
restaurant1 = Restaurant("vicenci", "pizza", 23)
restaurant2 = Restaurant("panda express", "chinese", 1)

restaurant1.numberServed = 25
restaurant1.restaurantCustomers()

restaurant1.updateCostumers(344)
restaurant1.restaurantCustomers()

restaurant1.incrementNumberServed(4)
restaurant1.restaurantCustomers()
# Out:
# 25
# 344
# 348

# %%
class User():
    def __init__(self, first, last, age, nat, loginAttempts):
        self.first = first
        self.last = last
        self.age = age
        self.nat = nat
        self.loginAttempts = 0

    def describeUser(self):
        print("\nFirst name: " + self.first.title())
        print("Last name: " + self.last.title())
        print("Age: " + str(self.age))
        print("Nationality: " + self.nat)

    def greetUser(self):
        print("\nHi, " + self.first.title() + " welcome to my hotel")

    def printLoginAttempts(self):
        print("Login attempts: " + str(self.loginAttempts))

    def incrementLoginAttempts(self):
        self.loginAttempts += 1

    def resetLoginAttempts(self):
        self.loginAttempts = 0

# %%
user1 = User("Miguel", "Marquez", 21, "mexicana", 1)
user1.incrementLoginAttempts()
user1.printLoginAttempts()

user1.incrementLoginAttempts()
user1.incrementLoginAttempts()
user1.incrementLoginAttempts()
user1.printLoginAttempts()

user1.resetLoginAttempts()
user1.printLoginAttempts()
# Out:
# Login attempts: 1
# Login attempts: 4
# Login attempts: 0

# %% [markdown]
# # Inheritance

# %%
#class Car():
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer = 10

    def getDescriptive(self):
        long_name = str(self.year) + " " + self.make + " " + self.model
        return long_name.title()

    def readOdometer(self):
        print("This car has " + str(self.odometer) + " miles on it")

    def updateOdometer(self, mileage):
        if mileage >= self.odometer:
            self.odometer = mileage
        else:
            print("You can´t roll back an odometer!")

    def incrementOdometer(self, miles):
        self.odometer += miles


class Battery():
    def __init__(self, battery_size = 70):
        self.battery_size = battery_size

    def upgrade_battery(self):
        self.battery_size = 85

    def descrive_battery(self):
        print("This car has a " + str(self.battery_size) + "-kWh batttery")

    def get_range(self):
        if self.battery_size == 70:
            range = 240
        elif self.battery_size == 85:
            range = 270

        message = "This car can go approximately " + str(range)
        message += " miles on a full charge."
        print(message)

# %%
class ElectricCar(Car):
    def __init__(self, make, model, year):
        super().__init__(make, model, year)
        self.battery = Battery()

    def describe_battery(self):
        print("This car has a " + str(self.battery_size) + "-kWh battery.")

    def fill_gas_tank():
        print("This car doesn´t need a gas tank!")

# my_tesla = ElectricCar("tesla", "model s", 2016)
# print(my_tesla.getDescriptive())
# my_tesla.battery.descrive_battery()
# my_tesla.battery.get_range()

carElectric = ElectricCar("mercedes", "model x", 2016)
carElectric.battery.get_range()
carElectric.battery.upgrade_battery()
carElectric.battery.get_range()
# Out:
# This car can go approximately 240 miles on a full charge.
# This car can go approximately 270 miles on a full charge.

# %%
# try it yourself

class Restaurant():

    def __init__(self, restaurantName, cuisineType):
        self.restaurantName = restaurantName
        self.cuisineType = cuisineType

    def describeRestaurant(self):
        print("The name´s restaurant is" + self.restaurantName)
        print("Our cuisine is " + self.cuisineType)

    def openRestaurant():
        print("The restaurant is open!")


class IceCreamStand(Restaurant):
    def __init__(self, restaurantName, cuisineType):
        super().__init__(restaurantName, cuisineType)
        self.flavors = ["limon", "vainilla", "cajeta"]

    def flavorsPrint(self):
        print("The flavors of ice cream are: ")
        for flavor in self.flavors:
            print(flavor)

iceCream = IceCreamStand("la viñika", "mexicana")
iceCream.flavorsPrint()
# Out:
# The flavors of ice cream are:
# limon
# vainilla
# cajeta

# %%
class User():
    def __init__(self, first, last, age, nat, loginAttempts):
        self.first = first
        self.last = last
        self.age = age
        self.nat = nat
        self.loginAttempts = 0

    def describeUser(self):
        print("\nFirst name: " + self.first.title())
        print("Last name: " + self.last.title())
        print("Age: " + str(self.age))
        print("Nationality: " + self.nat)

    def greetUser(self):
        print("\nHi, " + self.first.title() + " welcome to my hotel")

    def printLoginAttempts(self):
        print("Login attempts: " + str(self.loginAttempts))

    def incrementLoginAttempts(self):
        self.loginAttempts += 1

    def resetLoginAttempts(self):
        self.loginAttempts = 0

class Admin(User):
    def __init__(self, first, last, age, nat, loginAttempts):
        super().__init__(first, last, age, nat, loginAttempts)
        self.privileges = Privileges()

class Privileges(Admin):
    def __init__(self):
        self.priv = ["You can leave", "You can run", "You can scream"]

    def show_privileges(self):
        print("These are the privileges of the admin")
        for privilege in self.priv:
            print(privilege)

adminUser = Privileges()
adminUser.show_privileges()
# Out:
# These are the privileges of the admin
# You can leave
# You can run
# You can scream

# %% [markdown]
# # The python standard library

# %%
from collections import OrderedDict

favorite_languages = OrderedDict()

favorite_languages['jen'] = 'python'
favorite_languages['sarah'] = 'c'
favorite_languages['edward'] = 'ruby'
favorite_languages['phil'] = 'python'

for name, langueage in favorite_languages.items():
    print(name.title() + "'s favorite language is " + langueage.title())
# Out:
# Jen's favorite language is Python
# Sarah's favorite language is C
# Edward's favorite language is Ruby
# Phil's favorite language is Python

# %%
# Try it yourself

glossary = OrderedDict()

glossary["lower"] = "allows to low every character in a word"
glossary["for"] = "allow to work with every item in a list"
glossary["in"] = "allow to check if a item is in a list"

for key, mean in glossary.items():
    print(key + ": " + mean)
# Out:
# lower: allows to low every character in a word
# for: allow to work with every item in a list
# in: allow to check if a item is in a list

# %%
# random number

from random import randint
x = randint(1,100)
x
# Out:
# 30

# %%
import random

class Die:
    def __init__(self, sides=6):
        self.sides = sides  # Attribute with default value 6

    def roll_die(self):
        # Roll a random number between 1 and the number of sides
        roll = random.randint(1, self.sides)
        print(f"Rolled: {roll}")

# Create a 6-sided die
six_sided_die = Die()

# Roll the die 10 times
print("Rolling a 6-sided die 10 times:")
for _ in range(10):
    six_sided_die.roll_die()
# Out:
# Rolling a 6-sided die 10 times:
# Rolled: 3
# Rolled: 2
# Rolled: 4
# Rolled: 5
# Rolled: 5
# Rolled: 4
# Rolled: 2
# Rolled: 4
# Rolled: 6
# Rolled: 3
