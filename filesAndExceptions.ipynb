# %% [markdown]
# # Reading From a file

# %%
with open("pi_digits.txt") as file_object:
    contents = file_object.read()
    print(contents.rstrip())
# Out:
# 3.1415926535
#   8979323846
#   2643383279

# %%
# File paths
# with open('text_files/filename.txt') as file_object:

# With windows:
#file_path = "C:\Users\milma\OneDrive\Documentos\CS\Programación\ArchivosPython\CrashCourse\pi_digits.txt"
#with open(file_path) as file_object:

# %%
filename = "pi_digits.txt"

with open(filename) as file_object:
    for line in file_object:
        print(line.rstrip())
# Out:
# 3.1415926535
#   8979323846
#   2643383279

# %%
# making a list of lines from a file

with open(filename) as file_object:
    lines = file_object.readlines()

for line in lines:
    print(line)
# Out:
# 3.1415926535
#
#   8979323846
#
#   2643383279

# %%
# working with a files contents

pi_string = ""
for line in lines:
    pi_string += line.strip()

print(pi_string)
print(len(pi_string))
# Out:
# 3.141592653589793238462643383279
# 32

# %%
filename = "pi_string.txt"

with open(filename) as file_object:
    lines = file_object.readlines()

pi_string = ""
for line in lines:
    pi_string += line.strip()

print(pi_string[:52] + "....")
print(len(pi_string))
# Out:
# 3.14159265358979323846264338327950288419716939937510....
# 52

# %%
with open("learning_python.txt") as file_object:
    contents = file_object.read()
    print(contents*3)
# Out:
# I learn how to use python in my computer,
# I learn the importance of syntaxis in programing languages,
# I learn i need to practice to be a good programer.I learn how to use python in my computer,
# I learn the importance of syntaxis in programing languages,
# I learn i need to practice to be a good programer.I learn how to use python in my computer,
# I learn the importance of syntaxis in programing languages,
# I learn i need to practice to be a good programer.

# %%
print(contents)
# Out:
# I learn how to use python in my computer,
# I learn the importance of syntaxis in programing languages,
# I learn i need to practice to be a good programer.

# %%
filename = "learning_python.txt"

with open(filename) as file_object:
    lines = file_object.readlines()

for line in lines:
    print(line)
# Out:
# I learn how to use python in my computer,
#
# I learn the importance of syntaxis in programing languages,
#
# I learn i need to practice to be a good programer.

# %%
with open("learning_python.txt") as file_object:
    lines = file_object.readlines()
for line in lines:
    print(line.replace("python", "C++"))
# Out:
# I learn how to use C++ in my computer,
#
# I learn the importance of syntaxis in programing languages,
#
# I learn i need to practice to be a good programer.

# %% [markdown]
# # Writing fo a File

# %%
# writing to an empty file

filename = "programming.txt"

with open(filename, "w") as file_object:
    file_object.write("I love programming.\n")
    file_object.write("I love creating new games.\n")

# %%
# appending to a file

with open(filename, "a") as file_object:
    file_object.write("I also love finding meaning in large datasets. \n")
    file_object.write("I love creating apps that can run ina browser. \n")

# %%
# try it yourself

guests = "guest.txt"

with open(guests, "a") as file_object:
    run = True
    while run:
        print("Once you finish enter 'quit'")
        prompt = input("Enter your name: ")
        file_object.write(prompt + "\n")

        if prompt == "quit":
            run = False
# Out:
# Once you finish enter 'quit'
# Enter your name: diego
# Once you finish enter 'quit'
# Enter your name: miguel
# Once you finish enter 'quit'
# Enter your name: mariana
# Once you finish enter 'quit'
# Enter your name: victor
# Once you finish enter 'quit'
# Enter your name: quit

# %%
guestB = "guest_book.txt"

with open(guestB, "a") as file_object:
    run = True
    while run:
        print("What is your name?")
        prompt = input("enter your name: ")
        print("Welcome " + prompt)
        file_object.write(prompt + "\n")

        if prompt == "quit":
            run = False
# Out:
# What is your name?
# enter your name: MIGUEL
# Welcome MIGUEL
# What is your name?
# enter your name: DIEGO
# Welcome DIEGO
# What is your name?
# enter your name: MARIANA
# Welcome MARIANA
# What is your name?
# enter your name: quit
# Welcome quit

# %%
reasons = "reasons.txt"

with open(reasons, "a") as file_object:
    while True:
        prompt = input("Enter a reason for what you like programming: ")
        file_object.write(prompt + "\n")

        if prompt == "quit":
            break
# Out:
# Enter a reason for what you like programming: you can create
# Enter a reason for what you like programming: you can invent
# Enter a reason for what you like programming: quit

# %% [markdown]
# # Exceptions

# %%
# Handling the zeroDivisonError Exception

try:
    print(5/0)
except ZeroDivisionError:
    print("You can´t divide by zero")
# Out:
# You can´t divide by zero

# %%
# Using exceptions to prevent crashes

print("Give me two numbers, and I'll divide them.")
print("Enter 'q' to quit.")

while True:
    first_number = input("\nFirst number: ")
    if first_number == "q":
        break

    second_number = input("Second number: ")
    if second_number == "q":
        break
    try:
        answer = int(first_number) / int(second_number)
    except ZeroDivisionError:
        print("You can´t divide by 0!")
    else:
        print(answer)
# Out:
# Give me two numbers, and I'll divide them.
# Enter 'q' to quit.
#
# First number: 2
# Second number: 3
# 0.6666666666666666
#
# First number: 1
# Second number: 0
# You can´t divide by 0!
#
# First number: q

# %%
# Handling the FileNotFoundError Exception

filename = "alice.txt"

try:
    with open(filename) as f_obj:
        contents = f_obj.read()
except FileNotFoundError:
    msg = "Sorry, the file " + filename + " does not exist."
    print(msg)

# Analyzing text
else:
    words = contents.split()
    num_words = len(words)
    print("The file " + filename + "has about " + str(num_words) + " words")
# Out:
# Sorry, the file alice.txt does not exist.

# %%
# Working with multiple files

def count_words(filename):

    try:
        with open(filename) as f_obj:
            contents = f_obj.read()
    except FileNotFoundError:
        # Failing silently
        ## msg = "Sorry, the file " + filename + " does not exist."
        ## print(msg)
            pass

    # Analyzing text
    else:
        words = contents.split()
        num_words = len(words)
        print("The file " + filename + " has about " + str(num_words) + " words")

filenames = ["alice.txt", "siddhartha.txt", "moby_dick.txt"]
for filename in filenames:
    count_words(filename)
# Out:
# The file alice.txt has about 29564 words
# The file siddhartha.txt has about 42186 words

# %%
# Try it yourself

print("Hi, please insert two numers")

numberOne = input("Number one: ")
numberTwo = input("Number two: ")

try:
    sumOfNumbers = int(numberOne) + int(numberTwo)
    print(sumOfNumbers)
except ValueError:
    print("Sorry!, you have to input only numbers")
# Out:
# Hi, please insert two numers
# Number one: 2
# Number two: r
# Sorry!, you have to input only numbers

# %%
print("Hi, please insert two numers")
print("Once you finish, insert 'q'")

while True:
    numberOne = input("Number one: ")
    if numberOne == "q":
        break

    numberTwo = input("Number two: ")

    if numberTwo == "q":
            break
    try:
        sumOfNumbers = int(numberOne) + int(numberTwo)
        print("The sum of your numbers is " + str(sumOfNumbers))
    except ValueError:
        print("Sorry!, you have to input only numbers")
# Out:
# Hi, please insert two numers
# Once you finish, insert 'q'
# Number one: 3
# Number two: 4
# The sum of your numbers is 7
# Number one: 100
# Number two: 1
# The sum of your numbers is 101
# Number one: q

# %% [markdown]
# # Storing Data

# %%
# Using json.dump() and json.load()

import json

numbers = [2, 3, 5, 7, 11, 13]
filename = "numbers.json"
with open(filename, "w") as f_obj:
    json.dump(numbers, f_obj)

# %%
filename = "numbers.json"
with open(filename) as f_obj:
    numbers = json.load(f_obj)

print(numbers)
# Out:
# [2, 3, 5, 7, 11, 13]

# %%
# Saving and reading user-generated data

import json

username = input("What is your name? ")

filename = "username.json"
with open(filename, "w") as f_obj:
    json.dump(username, f_obj)
    print("We'll remember you when you come back, " + username )
# Out:
# What is your name? miguel
# We'll remember you when you come back, miguel

# %%
import json

filename = "username.json"

def get_stored_username():
    try:
        with open(filename) as f_obj:
            username = json.load(f_obj)
    except FileNotFoundError:
        return None
    else:
       return username

def get_new_username():
    username = input("What is your name? ")
    filename = "username.json"
    with open(filename, "w") as f_obj:
        json.dump(username, f_obj)
    return username

def greet_user():
    username = get_stored_username()
    if username:
        print("Welcome back, " + username)
    else:
        username = get_new_username()
        print("We'll remember you when you come back, " + username)

greet_user()
# Out:
# Welcome back, miguel

# %%
# Try it yourself

import json

filename = "numbers.json"

# Read existing numbers from the file
try:
    with open(filename, "r") as f_obj:
        numbers = json.load(f_obj)
    # Ensure numbers is a list even if the file contains something else
    if not isinstance(numbers, list):
        numbers = []
except (FileNotFoundError, json.JSONDecodeError):
    # If the file doesn't exist or is empty/invalid, start with an empty list
    numbers = []


userNumber = input("What is your favorite number? ")

if userNumber in numbers:
    print("Sorry, your number already exists in the list.")
else:
    numbers.append(userNumber)
    # Write the updated list back to the file
    with open(filename, "w") as f_obj:
        json.dump(numbers, f_obj)
    print("I know your favorite number! It's: " + userNumber)
# Out:
# What is your favorite number? 3
# Sorry, your number already exists in the list.

# %%
with open(filename) as f_obj:
    userNumbers = json.load(f_obj)

    if userNumbers in f_obj:
        print("Sorry, your number already exist")

    else:
        pass
