# %% [markdown]
# # How the input() function works

# %%
message = input("Tell me something, and I will repeat it back to you: ")
print(message)
# Out:
# Tell me something, and I will repeat it back to you: hola
# hola

# %%
name = input("Please enter your name: ")
print(name)
# Out:
# Please enter your name: miguel
# miguel

# %%
prompt = "If you tell us who you are, we can personalize the messages you see."
prompt += "\nWhat is your first name? "

name = input(prompt)
print("\nHello, " + name + "!")
# Out:
# If you tell us who you are, we can personalize the messages you see.
# What is your first name? miguel
#
# Hello, miguel!

# %%
# Using int() to accept numerical input

age = input("How old are you? ")

age = int(age)
age >= 21
# Out:
# How old are you? 21
# True

# %%
ageT = input("How old are you? ")
ageT = int(ageT)

if ageT < 18:
    print("Sorry, you can't drink alcohol")
else:
    print("You can drink alcohol")
# Out:
# How old are you? 34
# You can drink alcohol

# %%
# The modulo operator

5 % 10
# Out:
# 5

# %%
number = input("Enter a number, i will tell your if the number is even or odd: ")
number = int(number)

if number % 2 == 0:
    print("Your number is a even number")
else:
    print("Your number is a odd number")
# Out:
# Enter a number, i will tell your if the number is even or odd: 249589558943
# Your name is a odd number

# %%
# Try it yourself

rentalCar = input("What kind of rental car you want: ")
print("Let me see if I can find you a " + rentalCar)
# Out:
# What kind of rental car you want: sentra
# Let me see if I can find you a sentra

# %%
dinnerGroup = input("How many people are in your group: ")
dinnerGroup = int(dinnerGroup)

if dinnerGroup > 8:
    print("You have to wait")
else:
    print("Welcome")
# Out:
# How many people are in your group: 2
# Welcome

# %%
multipleTen = "Enter a number and i will tell you if the number"
multipleTen += " is a multiple of ten"

multipleTen = input()
multipleTen = int(multipleTen)

if multipleTen % 10 == 0:
    print("Your number is a multiple of ten")
else:
    print("Your number is not a multiple of ten")
# Out:
# 294849490
# Your number is a multiple of ten

# %% [markdown]
# # Introducing while loops

# %%
# The while loop in action

number = 1

while number <= 5:
    print(number)
    number += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Letting the user choose when to quit

prompt = "Tell me something, and I will repeat it back to you: "
prompt += "\nEnter 'quit' to end the program "

message = ""

while message != "quit":
    message = input(prompt)

    if message != "quit":
        print(message)
# Out:
# Tell me something, and I will repeat it back to you:
# Enter 'quit' to end the program holi
# holi
# Tell me something, and I will repeat it back to you:
# Enter 'quit' to end the program quit
# quit
# Tell me something, and I will repeat it back to you:
# Enter 'quit' to end the program quit

# %%
# Using a flag

prompt = "Tell me something, and I will repeat it back to you: "
prompt += "\nEnter 'quit' to end the program "

active = True
while active:
    message = input(prompt)

    if message == "quit":
        active = False
    else:
        print(message)
# Out:
# Tell me something, and I will repeat it back to you:
# Enter 'quit' to end the program hola
# hola
# Tell me something, and I will repeat it back to you:
# Enter 'quit' to end the program perro
# perro
# Tell me something, and I will repeat it back to you:
# Enter 'quit' to end the program quit

# %%
# Using break to exit a loop

prompt = "\nPlease enter the name of a city you have visited:"
prompt += "\n(Enter 'quit' when you are finished.) "

while True:
    city = input(prompt)

    if city == "quit":
        break
    else:
        print("I'd love to go to " + city.title() + "!")
# Out:
# Please enter the name of a city you have visited:
# (Enter 'quit' when you are finished.) leon
# I'd love to go to Leon!
#
# Please enter the name of a city you have visited:
# (Enter 'quit' when you are finished.) londres
# I'd love to go to Londres!
#
# Please enter the name of a city you have visited:
# (Enter 'quit' when you are finished.) quit

# %%
# Using continue in a loop

number = 0

while number < 10:
    number += 1
    if number % 2 == 0:
        continue

    print(number)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# Avoiding infinite loops

x = 1

while x < 5:
    print(x)
    x += 1
# Out:
# 1
# 2
# 3
# 4

# %%
# Try it yourself

pizzaPrompt = "Enter the toppings that you want in your pizza:"
pizzaPrompt += "\nEnter quit when you finish"

message = ""

while message != "quit":
    message = input(pizzaPrompt)

    print(message + " added to your pizza")
# Out:
# Enter the toppings that you want in your pizza:
# Enter quit when you finishhola
# hola added to your pizza
# Enter the toppings that you want in your pizza:
# Enter quit when you finishpiña
# piña added to your pizza
# Enter the toppings that you want in your pizza:
# Enter quit when you finishquit
# quit added to your pizza

# %%
from ast import Break
agePerson = "Enter your age to know the cost of your ticket"
agePerson += "\nOnce you finish, enter 'quit'"

cost = ""
run = True

while run:
    cost = input(agePerson)

    if cost == "quit":
        run = False
    else:
        cost = int(cost)
        if cost < 3:
            print("Your ticket is free")

        elif cost < 12:
            print("Your ticket cost is $10")

        elif cost > 12:
            print("Your ticket is $15")
# Out:
# Enter your age to know the cost of your ticket
# Once you finish, enter 'quit'3
# Your ticket cost is $10
# Enter your age to know the cost of your ticket
# Once you finish, enter 'quit'1
# Your ticket is free
# Enter your age to know the cost of your ticket
# Once you finish, enter 'quit'9
# Your ticket cost is $10
# Enter your age to know the cost of your ticket
# Once you finish, enter 'quit'quit

# %% [markdown]
# # Using a while loop with lists and dictionaries

# %%
# Moving items from one list to another

unconfirmed_users = ['alice', 'brian', 'candace']
confirmed_users = []

while unconfirmed_users:
    current_user = unconfirmed_users.pop()

    print("Verifyng user: " + current_user.title())
    confirmed_users.append(current_user)

print("The following users have been confirmed: ")
for confirmed_user in confirmed_users:
    print(confirmed_user.title())
# Out:
# Verifyng user: Candace
# Verifyng user: Brian
# Verifyng user: Alice
# The following users have been confirmed:
# Candace
# Brian
# Alice

# %%
# Removing all instances of specific values from a list

pets = ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
print(pets)

while "cat" in pets:
    pets.remove("cat")

print(pets)
# Out:
# ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
# ['dog', 'dog', 'goldfish', 'rabbit']

# %%
# Filling a dictionary with user input

responses = {}

polling_active = True

while polling_active:
    name = input("\nWhat is your name?")
    response = input("Which mountain would you like to climb someday?")

    responses[name] = response

    repeat = input("Would you like to let another person respond? (yes/no)")
    if repeat == "no":
        polling_active = False

print("\n--- Poll relusts ---")
for name, response in responses.items():
    print(name + " would like to climb " + response + ".")
# Out:
# What is your name?miguel
# Which mountain would you like to climb someday?sierra de lobos
# Would you like to let another person respond? (yes/no)no
#
# --- Poll relusts ---
# miguel would like to climb sierra de lobos.

# %%
# Try it yourself

sandwich_orders = ["hawaii", "pastrami", "jamon", "pastrami", "queso", "pastrami",]
finished_sandwiches = []

print("deli has out of pastrami")
while "pastrami" in sandwich_orders:
    sandwich_orders.remove("pastrami")

while sandwich_orders:
    sandwich = sandwich_orders.pop()
    finished_sandwiches.append(sandwich)

    print("I made your " + sandwich + " sandwich")

print(finished_sandwiches)
# Out:
# deli has out of pastrami
# I made your queso sandwich
# I made your jamon sandwich
# I made your hawaii sandwich
# ['queso', 'jamon', 'hawaii']

# %%
visitPlace = []

run = True
while run:
    print("If you could visit one place in the world, where would you go?")
    place = input("Enter de place: ")

    visitPlace.append(place)

    print("Have you already finish to add all the places?")
    finish = input("yes/no: ")

    if finish == "yes":
        run = False


print("The interviewee wants to visit: ")
for places in visitPlace:
    print(places)
# Out:
# If you could visit one place in the world, where would you go?
# Enter de place: leon
# Have you already finish to add all the places?
# yes/nono
# If you could visit one place in the world, where would you go?
# Enter de place: cholula
# Have you already finish to add all the places?
# yes/nosevilla
# If you could visit one place in the world, where would you go?
# Enter de place: sevilla
# Have you already finish to add all the places?
# yes/noyes
# The interviewee wants to visit:
# leon
# cholula
# sevilla
